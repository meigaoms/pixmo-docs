# %%
import datasets
import pandas as pd
mydata = datasets.load_from_disk("./OUTPUT/test_hf")
df = pd.DataFrame(mydata)
display(df)
# Out:
#                                             metadata  \
# 0  {"_pipeline": "HTMLDocumentPipeline", "persona...
# 1  {"_pipeline": "HTMLDocumentPipeline", "persona...
# 2  {"_pipeline": "HTMLDocumentPipeline", "persona...
# 3  {"_pipeline": "HTMLDocumentPipeline", "persona...
# 4  {"_pipeline": "HTMLDocumentPipeline", "persona...
#
#                                                topic  \
# 0  Aviation Carbon Footprint Report: A comprehens...
# 1  Annual Equipment Maintenance and Repair Log fo...
# 2  Annual Report on the Impact of Substance Abuse...
# 3  Green Certifications and Incentives for Pilots...
# 4  Monthly Meeting Agenda and Minutes for Bereave...
#
#                                                 data  \
# 0  {\n  "title": "Aviation Carbon Footprint Repor...
# 1  {\n  "AnnualEquipmentMaintenanceAndRepairLog20...
# 2  {\n  "title": "Annual Report on the Impact of ...
# 3  {\n  "title": "Green Certifications and Incent...
# ...

# %%
df["image"].iloc[3]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1282x2378>
